# %% [markdown]
# # ML Funnel
# 1. The given dataset, after data cleaning, and EDA, is visualized using coordinate geometry first. The goal of the ML algorithm can be determined from the visual understanding of the plot, and hence an intuition is gained on what needs to be achieved.
# 2. Then linear algebra is used to form equation from the intuition gained from the plot.
# 3. The linear algebraic equation is then used to develop an algorithm, which is then trained to build the ML model.
#
# Alternatively,
# 1. The given dataset is visualized using coordinate geometry.
# 2. Intuition is used to decide upon the best geometric shape that divides the labels.
# 3. Then linear algebra is used to form the equation that defines the geometric shape.
# 4. The equation is then used to build the ML algorithm.
# 5. The ML algorithm is trained with seen data to build the ML model.
# 6. Unseen data is then fed to this ML model that makes the prediction.

# %% [markdown]
# # Fish Sorting (A Classic ML Example)
# Watch: https://www.youtube.com/watch?v=y0U0KWjjOuw
#
# ![fish_sorting.png](attachment:fish_sorting.png)
#
# The sensor could be measuring,
# - Length.
# - Width.
# - Color.
# - Weight.

# %% [markdown]
# # Labelled Data
# Say that an ML model needs to be built that performs the task of sorting the fishes.
#
# A lot of data is required to train the ML model. The data can be properties, and categories of fishes. For example,
#
# | Width | Length | Weight | Type |
# | :-: | :-: | :-: | :-: |
# | 30 | 50 | 80 | 1 |
# | 11 | 23 | 28 | 2 |
# | 27 | 43 | 29 | 1 |
# | 16 | 31 | 36 | 2 |
#
# Using this data, a logic can be written to classify the fishes. But this is not a desirable approach, as it would require to hard code the boundaries. Instead, this data can be fed to an ML algorithm, and this ML algorithm should inturn decide the boundaries for classification.
#
# This is what ML is in a nutshell.
#
# Example,
#
# ![fish_sorting.png](attachment:fish_sorting.png)
#
# This model figures out the rules, and threshold to classify. Once the model is trained, new data (unseen data) can be fed to it, and the model learns, and proceeds with the classification.
#
# The "type" column in the table is the labelled data.
