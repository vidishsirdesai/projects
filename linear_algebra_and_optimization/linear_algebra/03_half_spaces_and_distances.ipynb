# %% [markdown]
# # Trigonometry Of Angles
#
# ![trigonometry_1.png](attachment:trigonometry_1.png)
#
# - $\sin\theta = \frac{P}{H}$.
# - $\cos\theta = \frac{B}{H}$.
# - $\tan\theta = \frac{P}{B}$.

# %% [markdown]
# # Shifting Lines
