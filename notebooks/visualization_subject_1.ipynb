# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
pd.set_option("display.max_columns", None)
sns.set_theme(style = "darkgrid")
warnings.filterwarnings("ignore")

# %%
# lift
df = pd.read_csv("../data/subject_1/lift.csv")
df.head()
# Out:
#       x     y    z
# 0  0.04  0.05  1.0
# 1  0.04  0.05  1.0
# 2  0.04  0.05  1.0
# 3  0.04  0.05  1.0
# 4  0.04  0.04  1.0

# %%
print(df["x"].max(), df["x"].min())
print(df["y"].max(), df["y"].min())
print(df["z"].max(), df["z"].min())
# Out:
# 0.87 -0.02
# 0.25 -0.02
# 1.32 0.37

# %%
plt.figure(figsize = (10, 5))
df["x"].plot()
# Out:
# <Axes: >

# %%
plt.figure(figsize = (10, 5))
df["y"].plot()
# Out:
# <Axes: >

# %%
plt.figure(figsize = (10, 5))
df["z"].plot()
# Out:
# <Axes: >

# %%
# roll_left
df = pd.read_csv("../data/subject_1/roll_left.csv")
df.head()
# Out:
#       x     y    z
# 0  0.03  0.02  1.0
# 1  0.04  0.02  1.0
# 2  0.04  0.02  1.0
# 3  0.04  0.02  1.0
# 4  0.04  0.02  1.0

# %%
print(df["x"].max(), df["x"].min())
print(df["y"].max(), df["y"].min())
print(df["z"].max(), df["z"].min())
# Out:
# 0.12 -0.06
# 0.11 -0.87
# 1.14 0.45

# %%
plt.figure(figsize = (10, 5))
df["x"].plot()
# Out:
# <Axes: >

# %%
plt.figure(figsize = (10, 5))
df["y"].plot()
# Out:
# <Axes: >

# %%
plt.figure(figsize = (10, 5))
df["z"].plot()
# Out:
# <Axes: >

# %%
# roll_right
df = pd.read_csv("../data/subject_1/roll_right.csv")
df.head()
# Out:
#       x     y    z
# 0  0.03  0.03  1.0
# 1  0.04  0.03  1.0
# 2  0.04  0.03  1.0
# 3  0.04  0.02  1.0
# 4  0.04  0.03  1.0

# %%
print(df["x"].max(), df["x"].min())
print(df["y"].max(), df["y"].min())
print(df["z"].max(), df["z"].min())
# Out:
# 0.12 -0.1
# 1.02 -0.05
# 1.23 0.41

# %%
plt.figure(figsize = (10, 5))
df["x"].plot()
# Out:
# <Axes: >

# %%
plt.figure(figsize = (10, 5))
df["y"].plot()
# Out:
# <Axes: >

# %%
plt.figure(figsize = (10, 5))
df["z"].plot()
# Out:
# <Axes: >
